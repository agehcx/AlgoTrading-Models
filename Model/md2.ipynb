# %%
pip list
# Out:
# Package                   Version
# ------------------------- ------------
# appdirs                   1.4.4
# asttokens                 2.4.1
# attrs                     23.2.0
# beautifulsoup4            4.12.3
# cattrs                    23.2.3
# certifi                   2024.2.2
# cffi                      1.16.0
# charset-normalizer        3.3.2
# colorama                  0.4.6
# colorlover                0.3.0
# comm                      0.2.1
# contourpy                 1.2.0
# cufflinks                 0.17.3
# cycler                    0.12.1
# debugpy                   1.8.0
# decorator                 5.1.1
# easygui                   0.98.3
# empyrical                 0.5.5
# et-xmlfile                1.1.0
# executing                 2.0.1
# fastjsonschema            2.19.1
# fmz                       2.2.0
# fonttools                 4.47.2
# frozendict                2.4.0
# h11                       0.14.0
# html5lib                  1.1
# ...

# %%
# %pip uninstall fmz
