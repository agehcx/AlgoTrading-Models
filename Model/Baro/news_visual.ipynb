# %%
import pandas as pd

# %%
df = pd.read_csv("counted_news.csv")

# %%
df.head(10)
# Out:
#    Unnamed: 0        Date                                          stockList  \
# 0           0  2024-01-01  ['AAI', 'AAI', 'AI', 'AI', 'AOT', 'AOT', 'BBL'...
# 1           1  2024-01-02  ['AAV', 'ADVANC', 'ADVANC', 'ADVANC', 'AI', 'A...
# 2           2  2024-01-03  ['AAV', 'AAV', 'AAV', 'AEONTS', 'AGE', 'AH', '...
# 3           3  2024-01-04  ['A5', 'AAV', 'AAV', 'ACG', 'ADVANC', 'AH', 'A...
# 4           4  2024-01-05  ['A5', 'A5', 'AAV', 'ACG', 'ADVANC', 'ADVANC',...
# 5           5  2024-01-06  ['24CS', 'AAI', 'AAV', 'AI', 'AI', 'AI', 'AI',...
# 6           6  2024-01-07  ['ADVANC', 'AI', 'AMA', 'AOT', 'AP', 'AP', 'B'...
# 7           7  2024-01-08  ['ADVANC', 'AF', 'AGE', 'AI', 'AI', 'AI', 'AI'...
# 8           8  2024-01-09  ['AAV', 'AAV', 'AAV', 'ADVANC', 'ADVANC', 'ADV...
# 9           9  2024-01-10  ['AAV', 'ADVANC', 'AI', 'AI', 'AI', 'AI', 'AI'...
#
#                                             StockSet  totalCount maxMentioned  \
# ...
