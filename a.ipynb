# %%
print("Hello World From Jupyter")
# Out:
# Hello World From Jupyter

# %%
print("HI THERE")
# Out:
# HI THERE

# %%
import pandas as pd

# Creating a dictionary with the selected performance stats and additional columns
data = {
    "Security": ["S50H0^2", "S50M0^2", "S50U0^2", "S50Z0^2", "S50H1^2", "S50M1^2", "S50U1^2", "S50Z1^2", "S50H2^2", "S50M2^2", "S50U2^2", "S50Z2^2", "S50H3^2", "S50M3^2", "S50U3^2", "S50Z3^2"],
    "Total Return [%]": [41.704557, 6.713937, 4.423169, 6.813926, 53.277815, 22.574422, 6.680975, 7.916722, 18.885259, 29.146333, 24.776484, 7.227958, 19.445599, 17.071477, 22.331442, 31.11753],
    "Max Drawdown [%]": [6.220371, 26.026829, 33.373688, 23.886098, 17.392905, 20.965309, 14.96157, 9.930399, 6.861059, 5.143012, 9.145058, 9.279444, 5.576631, 7.429403, 4.66216, 8.365762],
    "Total Trades": [7, 11, 11, 13, 16, 13, 12, 19, 11, 9, 13, 8, 19, 8, 12, 13],
    "Win Rate [%]": [83.333333, 60.0, 50.0, 41.666667, 80.0, 75.0, 72.727273, 61.111111, 80.0, 87.5, 58.333333, 57.142857, 77.777778, 71.428571, 72.727273, 57.142857],
    "Profit Factor": [13.8095, 1.0880, 0.9216, 1.1603, 5.5918, 2.5280, 3.2996, 1.6718, 5.0078, 9.8261, 3.6000, 1.9130, 8.6670, 7.1170, 5.9922, 4.2180],
    "Sharpe Ratio": [4.2175, 0.6446, 0.4238, 0.4502, 2.5163, 1.2935, 0.5535, 0.8274, 2.0590, 2.9011, 2.5731, 0.9301, 2.3040, 2.0184, 2.4586, 2.1783],
    "Start Date": ["2023-01-02", "2023-01-02", "2023-01-02", "2023-01-02", "2023-01-02", "2023-01-02", "2023-01-02", "2023-01-02", "2023-01-02", "2023-01-02", "2023-01-02", "2023-01-02", "2023-01-02", "2023-01-02", "2023-01-02", "2023-01-02"],
    "Trade Length (days)": [120, 150, 140, 130, 160, 155, 145, 170, 135, 125, 150, 110, 165, 115, 140, 150]
}

# Creating the DataFrame
df = pd.DataFrame(data)

print(df)
# Out:
#    Security  Total Return [%]  Max Drawdown [%]  Total Trades  Win Rate [%]  \
# 0   S50H0^2         41.704557          6.220371             7     83.333333
# 1   S50M0^2          6.713937         26.026829            11     60.000000
# 2   S50U0^2          4.423169         33.373688            11     50.000000
# 3   S50Z0^2          6.813926         23.886098            13     41.666667
# 4   S50H1^2         53.277815         17.392905            16     80.000000
# 5   S50M1^2         22.574422         20.965309            13     75.000000
# 6   S50U1^2          6.680975         14.961570            12     72.727273
# 7   S50Z1^2          7.916722          9.930399            19     61.111111
# 8   S50H2^2         18.885259          6.861059            11     80.000000
# 9   S50M2^2         29.146333          5.143012             9     87.500000
# 10  S50U2^2         24.776484          9.145058            13     58.333333
# ...

# %%
df
# Out:
#    Security  Total Return [%]  Max Drawdown [%]  Total Trades  Win Rate [%]  \
# 0   S50H0^2         41.704557          6.220371             7     83.333333
# 1   S50M0^2          6.713937         26.026829            11     60.000000
# 2   S50U0^2          4.423169         33.373688            11     50.000000
# 3   S50Z0^2          6.813926         23.886098            13     41.666667
# 4   S50H1^2         53.277815         17.392905            16     80.000000
# 5   S50M1^2         22.574422         20.965309            13     75.000000
# 6   S50U1^2          6.680975         14.961570            12     72.727273
# 7   S50Z1^2          7.916722          9.930399            19     61.111111
# 8   S50H2^2         18.885259          6.861059            11     80.000000
# 9   S50M2^2         29.146333          5.143012             9     87.500000
# 10  S50U2^2         24.776484          9.145058            13     58.333333
# ...
